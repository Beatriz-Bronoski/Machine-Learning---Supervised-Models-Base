# %% [markdown]
# ### 📦 Imports
# Most common imports on data science

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 🎲 Import data
# Ways to import your data ( Most Used )

# %%
df_csv = pd.read_csv()
df_excel = pd.read_excel()
df = pd.read_parquet()
df_json = pd.read_json()

# %% [markdown]
# ### 📋 Data Description
# Get statistics and data structure description

# %%
# To get main statistics as average, min, max, std, quartiles
df.describe()
# To get data types and non-null counts
df.info()
# To get the first 5 rows of the dataframe
df.head()   
# To get the last 5 rows of the dataframe
df.tail()
# To get the shape of the dataframe (rows, columns)
df.shape
# To get the column names
df.columns
# List collumns names
df.columns.tolist()

# %% [markdown]
# ### 🔎 Data Cleaning

# %%
# Drop duplicates
df.drop_duplicates(inplace=True)
# Drop missing values
df.dropna(inplace=True)
# Fill missing values with a specific value
df.fillna(value=0, inplace=True)
# Fill missing values with the mean of the column
df.fillna(df.mean(), inplace=True)
